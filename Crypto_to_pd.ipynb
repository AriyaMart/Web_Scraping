# %% [markdown]
# # **Collect Crypto's price --> Pandas by using an easy method(pd.read_html)**
# - Author       : Ariya Boonsri
# - Github     : https://github.com/AriyaMart
# - LinkedIn   : https://www.linkedin.com/in/ariya-boonsri-454725227/
# - Website     : https://coinmarketcap.com/
#
# - Date  : 14 April 2022
#
# ---

# %%
pd.Timestamp.today()
# Out:
# Timestamp('2022-04-14 14:07:51.373380')

# %%
import pandas as pd

# %%
url = 'https://coinmarketcap.com/'
#using pd.read_html
df=pd.read_html(url)
df
# Out:
# [    Unnamed: 0    #                         Name       Price  24h %   7d %  \
#  0          NaN  1.0               Bitcoin1BTCBuy  $41,200.96  3.04%  5.16%
#  1          NaN  2.0              Ethereum2ETHBuy   $3,106.66  1.95%  3.44%
#  2          NaN  3.0                  Tether3USDT       $1.00  0.01%  0.00%
#  3          NaN  4.0                   BNB4BNBBuy     $420.78  0.79%  2.34%
#  4          NaN  5.0                USD Coin5USDC     $0.9996  0.03%  0.03%
#  ..         ...  ...                          ...         ...    ...    ...
#  95         NaN  NaN                     KavaKAVA       $4.37    NaN    NaN
#  96         NaN  NaN  Kyber Network Crystal v2KNC       $4.23    NaN    NaN
#  97         NaN  NaN                      ICONICX       $0.79    NaN    NaN
#  98         NaN  NaN                    IoTeXIOTX       $0.08    NaN    NaN
#  99         NaN  NaN                     BORABORA       $0.84    NaN    NaN
#
# ...

# %%
df=df[0]
df
# Out:
#     Unnamed: 0    #                         Name       Price  24h %   7d %  \
# 0          NaN  1.0               Bitcoin1BTCBuy  $41,200.96  3.04%  5.16%
# 1          NaN  2.0              Ethereum2ETHBuy   $3,106.66  1.95%  3.44%
# 2          NaN  3.0                  Tether3USDT       $1.00  0.01%  0.00%
# 3          NaN  4.0                   BNB4BNBBuy     $420.78  0.79%  2.34%
# 4          NaN  5.0                USD Coin5USDC     $0.9996  0.03%  0.03%
# ..         ...  ...                          ...         ...    ...    ...
# 95         NaN  NaN                     KavaKAVA       $4.37    NaN    NaN
# 96         NaN  NaN  Kyber Network Crystal v2KNC       $4.23    NaN    NaN
# 97         NaN  NaN                      ICONICX       $0.79    NaN    NaN
# 98         NaN  NaN                    IoTeXIOTX       $0.08    NaN    NaN
# 99         NaN  NaN                     BORABORA       $0.84    NaN    NaN
#
#                   Market Cap                         Volume(24h)  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '#', 'Name', 'Price', '24h %', '7d %', 'Market Cap',
#        'Volume(24h)', 'Circulating Supply', 'Last 7 Days', 'Unnamed: 10'],
#       dtype='object')

# %%
dfs=df.drop(['Unnamed: 0','#','Last 7 Days','Unnamed: 10'], axis=1) # 'Last 7day' is a graph
dfs
# Out:
#                            Name       Price  24h %   7d %  \
# 0                Bitcoin1BTCBuy  $41,200.96  3.04%  5.16%
# 1               Ethereum2ETHBuy   $3,106.66  1.95%  3.44%
# 2                   Tether3USDT       $1.00  0.01%  0.00%
# 3                    BNB4BNBBuy     $420.78  0.79%  2.34%
# 4                 USD Coin5USDC     $0.9996  0.03%  0.03%
# ..                          ...         ...    ...    ...
# 95                     KavaKAVA       $4.37    NaN    NaN
# 96  Kyber Network Crystal v2KNC       $4.23    NaN    NaN
# 97                      ICONICX       $0.79    NaN    NaN
# 98                    IoTeXIOTX       $0.08    NaN    NaN
# 99                     BORABORA       $0.84    NaN    NaN
#
#                   Market Cap                         Volume(24h)  \
# 0   $783.28B$783,278,134,033          $27,533,506,886668,273 BTC
# 1   $373.95B$373,952,178,347        $15,603,848,2295,022,709 ETH
# 2     $82.66B$82,664,969,624  $57,719,274,20957,708,009,271 USDT
# ...
